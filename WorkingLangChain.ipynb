# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import CharacterTextSplitter
#from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

import os
from langchain.document_loaders import PyPDFLoader, Docx2txtLoader, UnstructuredWordDocumentLoader

# %%
# Uncomment if you want to convert a CSV file into a Json file (csv should be in working directory)
# import pandas as pd
# import json
# import os

# def csv_to_json(csv_file_name, json_file_name):
#     # read csv file
#     data = pd.read_csv(csv_file_name)
    
#     # ensure the data frame columns are in string format
#     data = data.astype(str)

#     # convert dataframe to dict
#     data_dict = data.to_dict('records')

#     # write data to json file
#     with open(json_file_name, 'w') as json_file:
#         json.dump(data_dict, json_file)

# # prompt user to enter the csv file name
# csv_file_name = input("Enter the name of your CSV file (with .csv extension): ")

# # create the json file name
# json_file_name = os.path.splitext(csv_file_name)[0] + '.json'

# csv_to_json(csv_file_name, json_file_name)

# %%
import langchain.document_loaders
import json
import os

class JSONLoader:
    def __init__(self, filename):
        self.filename = filename

    def load_and_split(self):
        with open(self.filename, 'r') as f:
            data = json.load(f)
        return [json.dumps(record) for record in data]  # Splitting JSON objects

# Directory containing your documents
directory = "documents/"
# Get a list of all files in the directory
files = os.listdir(directory)
# Filter the list for .pdf, .docx, and .json files
pdf_files = [f for f in files if f.endswith('.pdf')]
docx_files = [f for f in files if f.endswith('.docx')]
json_files = [f for f in files if f.endswith('.json')]

print(f"PDF files: {pdf_files}")
print(f"DOCX files: {docx_files}")
print(f"JSON files: {json_files}")

pages = []

# Load each .pdf file and add its pages to the list
for file in pdf_files:
    loader = PyPDFLoader(os.path.join(directory, file))
    pages += loader.load_and_split()

# Load each .docx file and add its pages to the list
for file in docx_files:
    loader = Docx2txtLoader(os.path.join(directory, file))  # or UnstructuredWordDocumentLoader
    pages += loader.load_and_split()

# Load each .json file and add its data to the list
for file in json_files:
    loader = JSONLoader(os.path.join(directory, file))
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    texts = loader.load_and_split()
    
    pages += text_splitter.create_documents(texts)
    print(pages)
# Out:
# PDF files: []
# DOCX files: ['BEST PRACTICES 3.23.2023 ans.docx', 'BEST PRACTICES 1.12.2023 ans.docx', 'BEST PRACTICES 12.1.2022 ans.docx', 'BEST PRACTICES 5.18.2023 ans.docx', 'BEST PRACTICES 7.28.2022 ans.docx', 'BEST PRACTICES 2.9.2023 ans.docx', 'BEST PRACTICES 4.6.2023 ans.docx', 'BEST PRACTICES 3.9.2023 ans.docx', 'BEST PRACTICES 11.3.2022 ans.docx', 'BEST PRACTICES 1.26.2023 ans.docx', 'BEST PRACTICES 2.23.2023 ans.docx', 'BEST PRACTICES 9.8.2022 ans.docx']
# JSON files: ['CompiledCus.json']
# [Document(page_content='BEST PRACTICES 3/23/2023\n\nI know we’ve talked about similar issues regarding multiple risers on a pole. In the past, if we have a 2 phase riser in the same u-guard, we would split that into separate u-guards. \n\nWould you suggest to proceed with that design or would you suggest to keep in the same u-guard (if separating creates conflict with the preferred/maximum number of risers allowed)? \n\nBetter practice is to save space on poles for future risers. Put 1/2/3 primary risers at the time on construction under the same U-guard.\n\nHow it was explained to me in the past is that having two phases in the same riser/conduit creates a resonance frequency, causing the potential for the cable to heat and melt in the same riser/conduit, taking out both loops. Is this true and is this why separating is the preferred design? \n\nFerroresonance has much more to do with long parallel primary circuits than short 30 ft risers. Conserve the number risers, so a second can be added at a later date.\n\n\n\nCan you install an UG recloser with 1/0 ug primary? We were told to install the recloser and change the ends of the recloser to 300amp blades, but it doesn’t look like you can do that and it comes automatically with 600 amp switches. Do you know a spec and/or CU’s to accomplish this goal, if possible? \n\nNot per the spec in 28.15-101 series, these RCLs are for 600Acircuits , 1000KCM primary. Ask the Duke person assigning the work to explain it further?\n\n\n\nIn the spec book/CU library, aerial clamps (CLAMP-AER-CABLE-MD-F) don’t include a bolt in the materials. So when using this framing, should we call for the required bolt? \n\nIssue the bolt until directed not to.\n\nThere was some discussion about combining needed bolts within the device CUs. Might check for this situation. \n\n\n\nWith respect to the SEDS shown below, between “PED 220” and “PED 219” a 500-3 AL UG secondary was required to prevent customer flicker. \n\nWould it be better to also have a 500-3 AL sec riser instead of the 4/0? It seems that all the load would have to go through the 4/0 first and then the 500, creating somewhat of a “choke point” in required load.\n\nIf so, would you suggest 500AL leads coming out of the transformer as well (connecting to the 500-3 AL sec riser?\n\nFlicker is a result of a large motor (AC) starting caused by the instantaneous drop in voltage and in rush of current to start the motor rotating. The total impedance in the circuit from the transformer to the motor location is what determines the flicker. Therefore, the larger 500 KCM cables will lower the Z, lowering flicker %. \n\nThe 500 KCM cable could be anywhere in the circuit, now what is practical for Voltage drop and loading to locate the 500 close to the transformer.\n\nPlacing the 500 on the riser may oppositely complicate the connections at the transformer.', metadata={'source': 'documents/BEST PRACTICES 3.23.2023 ans.docx'}), Document(page_content='BEST PRACTICES 1-12-2023\n\nTYPICALLY IF THERE IS 2 SECONDARY RISERS ON A POLE, WE WOULD REMOVE BOTH, GO BACK WITH ONE, AND INSTALL A PED. COULD THIS WORK IF THE QTY OF MULTIPLEX DIFFERS?\n\nEXAMPLE: CURRENTLY A 1/0-3 AND A #6-2 GO DOWN TWO SEPARATE RISERS. CAN WE JUST GO BACK WITH ONE 2/0-3 AND INSTALL A PED? Yes, if you are talking about the same voltage base and phases. Multiple 120/240 single phase cables can be joined into one larger riser cable size. I would not combine 1PH and 3PH cables into one 3PH riser cable simply because it now causes difficulty in troubleshooting for the crew.\n\nIF WE NEED TO REPLACE A CONCRETE POLE WITH JU, DO WE NEED TO CALL FOR SOME POLE-CUTOFF CU OR IS THAT NOT REQUIRED SINCE ITS CONCRETE?\n\nNOTE: “POLE-WD-XX-AC-JU-REM-F” WOULD BE THE REMOVAL CU IF THE POLE WAS WOOD AND TRANSFER “JU-TRF-CABLE-MAIN-F”, BUT SINCE CONCRETE, DO WE JUST REMOVE “POLE-CTE-40-T3-F” AND TRANSFER “JU-TRF-CABLE-MAIN-F”? This maybe a Duke question given the new spun concrete pole usage, but what you are ...

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma

import openai
import config
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())  # read local .env file
openai.organization = config.OPENAI_ORG_KEY
openai.api_key = config.OPENAI_API_KEY

# %%
embeddings = OpenAIEmbeddings()
docsearch = Chroma.from_documents(pages, embeddings)
# Out:
# Using embedded DuckDB without persistence: data will be transient

# %%
# qa = RetrievalQA.from_chain_type(llm=OpenAI(), chain_type="stuff", retriever=docsearch.as_retriever(), return_source_documents=True)

# %%
# query = "What is the spec page for primary and neutral dead end assemblies?"
# result = qa({"query": query})

# %%
# result["result"]

# %%
#result["source_documents"]

# %%
def process_llm_response(llm_response):
    print(llm_response['result'])
    
    print('\n\nSources:')
    for index, source in enumerate(llm_response["source_documents"]):
        print(source)
        try:
            print(f"{index + 1}: {source.metadata['source']}, page = {source.metadata['page']}")
        except:
            try:
                print(f"{index + 1}: {source.metadata['source']}")
            except:
                pass

# %%
# query = "What Compatible units should I use for the single-phase construction - tangent post top insulator?"
# llm_response = qa(query)
# process_llm_response(llm_response)

# %%
from langchain.prompts import PromptTemplate
prompt_template = """Use the following pieces of context to answer the question. If you don't know the answer, just say that you don't know, don't try to make up an answer.
You are a problem solver and you are able to find information regarding any topic based on the context provided to you. Use reasoning to answer your question. First breakdown the steps to solve it and reason according to the context provided. You are smart, wise, and very meticulous in your work. You answer questions in an organized fashion and understand the importance of step by step thinking for problem solving. If you get a question about compatible units (CU) remember that the last letter denotes the state (e.g., CUs ending in -F denote Florida) 

{context}

Question: {question}
Answer:"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
llm = ChatOpenAI(
    temperature=1,
    model_name='gpt-3.5-turbo'
)

# %%
chain_type_kwargs = {"prompt": PROMPT}
# Another option is to use llm=OpenAI()
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever(), chain_type_kwargs=chain_type_kwargs, return_source_documents=True)

# %%
query = """How do I know if a transformer is single bushing or double bushing from the CU name? Give a comprehensive explanation"""
llm_response = qa(query)
process_llm_response(llm_response)
# Out:
# To determine if a transformer is single bushing or double bushing based on the CU name, we need to carefully analyze the information provided in the CU name and the context given.
#
# Based on the context provided, we can see that the CU name contains several codes and abbreviations. Let's break down the CU names and analyze each part:
#
# 1. "TF-OH" indicates that the transformer is an overhead transformer.
# 2. The number after "TF-OH" represents the kVA (kilovolt-ampere) rating of the transformer. For example, "TF-OH-75" indicates a 75kVA transformer.
# 3. The next number denotes the voltage rating of the primary side of the transformer. For example, "TF-OH-75-12KV" means the primary side voltage is 12 kilovolts.
# 4. The following "120/240V" indicates the secondary side voltage of the transformer, which is either 120V or 240V.
# 5. The "1P" in the CU name refers to single-phase, indicating that the transformer is designed to handle single-phase electrical systems.
# 6. The numbers after "1P" represent the number of bushings on the transformer. For example, "TF-OH-75-12KV-120/240V-1P-2BT-F" indicates that the transformer has two bushings.
# 7. The last letter in the CU name denotes the state or location. In this case, "F" denotes Florida.
#
# Based on the analysis of the above information, we can conclude the following:
#
# - If the CU name contains "1BT," it means that the transformer has single bushing. For example, "TF-OH-75-12KV-120/240V-1P-1BT-F" indicates a single bushing transformer.
# - If the CU name contains "2BT," it means that the transformer has double bushings. For example, "TF-OH-75-12KV-120/240V-1P-2BT-F" indicates a double bushing transformer.
#
# Therefore, by examining the number of bushings indicated in the CU name, we can determine if a transformer is single bushing or double bushing.
#
#
# Sources:
# page_content='{"CU Name": "TF-OH-75-25KV-120/240V-1P-2BT-F", "CU Alternate Name": "nan", "CU Legacy Name": "TFO75DTM25CF", "CU Description": "Transformer OH 75kVA 14.4/24.94Y kV 120/240V Single Phase Dual Bushing w/ Tapchanger Mild Steel", "Version": "1", "CU Level": "2", "Status": "ACTIVE", "LOB": "D"}' metadata={}
# page_content='{"CU Name": "TF-OH-50-13KV-120/240V-1P-2B-F", "CU Alternate Name": "nan", "CU Legacy Name": "TFO50DM13CF", "CU Description": "Transformer OH 50kVA 13.2GY/7.62 kV 120/240V Single Phase Dual Bushing Mild Steel", "Version": "1", "CU Level": "2", "Status": "ACTIVE", "LOB": "D"}' metadata={}
# page_content='{"CU Name": "TF-OH-5-12KV-120/240V-1P-2BT-F", "CU Alternate Name": "nan", "CU Legacy Name": "TFO5DTM12CF", "CU Description": "Transformer OH 5kVA 7.2/12.47Y kV 120/240V Single Phase Dual Bushing w/ Tapchanger Mild Steel", "Version": "1", "CU Level": "2", "Status": "ACTIVE", "LOB": "D"}' metadata={}
# page_content='{"CU Name": "TF-OH-75-12KV-120/240V-1P-1BT-F", "CU Alternate Name": "TF-OH-75-12KV-120/240V-1P-2BT-F", "CU Legacy Name": "TFO75STM12CF", "CU Description": "(UOP) REM ONLY---USE CU: TF-OH-75-12KV-120/240V-1P-2BT-F FOR INSTALLS. Transformer OH 75kVA 7.2/12.47Y kV 120/240V Single Phase Single Bushing w/ Tapchanger Mild Steel", "Version": "1", "CU Level": "2", "Status": "ACTIVE", "LOB": "D"}' metadata={}
